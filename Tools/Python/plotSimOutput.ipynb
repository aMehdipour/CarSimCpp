# %%
import pandas as pd
import catppuccin
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
numericalOut = pd.read_csv('/home/amehdipour/Repos/CarSimCpp/Output/04_20_2025_15_56_30/numerical_solution.csv')
exactOut = pd.read_csv('/home/amehdipour/Repos/CarSimCpp/Output/04_20_2025_15_56_30/exact_solution.csv')
comparisonOut = pd.read_csv('/home/amehdipour/Repos/CarSimCpp/Output/04_20_2025_15_56_30/comparison.csv')

# %%
plt.figure(figsize=(10, 6))
plt.plot(comparisonOut['Time'], comparisonOut['Exact_X'], label='Exact')
plt.plot(comparisonOut['Time'], comparisonOut['Num_X'], label='Numerical')
plt.xlabel('Time (s)')
plt.ylabel('Position Error (m)')
plt.title('Position Error')
plt.legend()
plt.grid()
plt.show()

# %%
print(numericalOut)
# Out:
#    Time  State0  State1
# 0     0       1       0

# %%
plt.figure(figsize=(10, 6))
plt.plot(simOut['Time'], simOut['Exact_V'], label='Exact')
plt.plot(simOut['Time'], simOut['Num_V'], label='Numerical')
plt.xlabel('Time (s)')
plt.ylabel('Velocity Error (m/s)')
plt.title('Velocity Error')
plt.legend()
plt.grid()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 2
#       1 plt.figure(figsize=(10, 6))
# ----> 2 plt.plot(simOut['Time'], simOut['Exact_V'], label='Exact')
#       3 plt.plot(simOut['Time'], simOut['Num_V'], label='Numerical')
#       4 plt.xlabel('Time (s)')
#
# NameError: name 'simOut' is not defined
